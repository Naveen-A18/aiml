# %%
print("Hello, Naveen! This is your first Python program.")
# Out:
# Hello, Naveen! This is your first Python program.

# %%
a = 5
b = 3
sum = a + b
print("The sum is:", sum)
# Out:
# The sum is: 8

# %%
name = input("Enter your name: ")
print("Welcome,", name)
# Out:
# Welcome, naveen

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Even number
