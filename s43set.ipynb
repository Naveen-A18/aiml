# %%
shop={"mob1","phone","laptop"}
shop.discard("phone")
print(shop)
# Out:
# {'mob1', 'laptop'}

# %%
my_set={11,22,33,44,55,66}
element=my_set.pop()
print(element)
print(my_set)
# Out:
# 33
# {66, 22, 55, 11, 44}

# %%
s1={4,5,6,7,8,}
s2={3,5,6,7,4,2}
dif_set=s2.difference(s1)
print(dif_set)
Union_set = s1.union(s2)
print(Union_set)
# Out:
# {2, 3}
# {2, 3, 4, 5, 6, 7, 8}

# %%
#write a program to input eight numbers from the usermand display all the unique numbers(once).
s = set()
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
n = int(input("number"))
s.add(n)
print(s)
# Out:
# {2, 3, 4}

# %%
#can we have a set with 18(int) and '18'(str) as a value in it?
s = set()
s.add(18)
s.add('18')
print(s)
# Out:
# {18, '18'}

# %%
#what will be the length of following set s: s=()s.add(20)

# %%
#s={} what is the type of 's'
s={}
print(type(s))
# Out:
# <class 'dict'>

# %%
#create an empty dictionary allow 4 frindes to enter their favorite language as value and use key as their names.assume that the names are unique
s={}
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
print(s)
# Out:
# {'chandan': 'python', 'naveen': 'c', 'gowtham': 'java', 'manju': 'html'}

# %%
#if the names of 2 friends are same; what will happen to the program in problem 6?
s={}
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
name = input("enter friend name :")
lang = input("enter the language:")
s.update({name:lang})
print(s)
# Out:
# {'n': 'p', 'c': 'h'}
