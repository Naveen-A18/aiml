# %%
#handeling the binary
f1=open(r"yoglogo.png","rb")
f2=open("picture.jpg","wb")
cont = f1.read()
print(cont)
f2.write(cont)

# %%
#pickle file
import pickle
data={"name":"john","age":"20","city":"bengalure"}
with open("data.pkl","wb")as file:
    pickle.dump(data,file)

# %%
with open("data.pkl","rb") as file:
    loaded_data = pickle.load(file)
    print(loaded_data)
# Out:
# {'name': 'john', 'age': '20', 'city': 'bengalure'}

# %%
# !pip install joblib
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#handling the large data and in machine learning for saving the model(trained algoritum)
import joblib
data={"name":"achraya","work":"education"}
joblib.dump(data,"file.joblib")
# Out:
# ['file.joblib']

# %%
load_data = joblib.load("file.joblib")
print(load_data)
# Out:
# {'name': 'achraya', 'work': 'education'}
