# %%
# Centered pyramid
n = int(input("Number of rows: "))   # e.g. 5

for i in range(1, n+1):
    # spaces on the left
    print(" " * (n - i) + "*" * (2*i - 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
n = int(input("enter the number :"))
for i in range(n,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
n=5
for i in range(1,n+1):
    print(""*(n-i)+"*"*i)
# Out:
# *
# **
# ***
# ****
# *****
