# %%
#write a program to create a dictionary of hindi words with values as thier english translation provide user with an option to look it up!
words = {
    "madad":"help",
    "aam":"mango",
    "paani":"water"
}
word = input("enter the word meaning of:")
print(words[word])
# Out:
# mango
