# %%
#write a python programing to display a user entered name followed by Good Afternoon using input() function
name = input("Enter your name: ")
print("Good Afternoon, " + name + "!")
# Out:
# Good Afternoon, naveen!

# %%
#to fill in letter template given below with name and date
# letter = '''Dear <|NAME|>,
#you are selected!
#Date: <|DATE|>'''

letter = '''Dear <|NAME|>,
you are selected!
Date: <|DATE|>'''   
name = input("Enter your name: ")
date = input("Enter date: ")    
letter = letter.replace("<|NAME|>", name)
letter = letter.replace("<|DATE|>", date)
print(letter)
# Out:
# Dear naveen,
# you are selected!
# Date: 31-08-2025

# %%
letter = '''Dear <|NAME|>,
you are selected!   
Date: <|DATE|>'''
name = input("Enter your name: ")
date = input("Enter date: ")
letter = letter.replace("<|NAME|>", name)
letter = letter.replace("<|DATE|>", date)
print(letter)
# Out:
# Dear N,
# you are selected!
# Date: 52

# %%
list1 = []
print(type(list1))
listint=[1,2,3,4,5]
print(listint)
#list with mixed datatypes
my_list = [1,"hello",67.78]
print(my_list)
#nested list
n_list = ["happy",2,3,45]
print(n_list)
# Out:
# <class 'list'>
# [1, 2, 3, 4, 5]
# [1, 'hello', 67.78]
# ['happy', 2, 3, 45]

# %%
shoplist = ["mango","banana","orange","grapes"]
print("i have ",len(shoplist),"item to buy")
# Out:
# i have  4 item to buy

# %%
#append
shoplist.append("apple")
print("my shoplist is ",shoplist)
# Out:
# my shoplist is  ['mango', 'banana', 'orange', 'grapes', 'apple', 'carrot', 'potato', 'apple']

# %%
#extend
shoplist.extend(["carrot","potato"])
print("my shoplist is ",shoplist)
# Out:
# my shoplist is  ['mango', 'banana', 'orange', 'grapes', 'apple', 'carrot', 'potato', 'apple', 'carrot', 'potato', 'carrot', 'potato', 'carrot', 'potato']

# %%
shoplist1 = ["moblie","laptop","tv","fridge"]

# %%
#concatination
shoplist = ["mango","banana","orange","grapes"]
shoplist1 = ["moblie","laptop","tv","fridge"]
main_shop = shoplist + shoplist1
print(main_shop)
# Out:
# ['mango', 'banana', 'orange', 'grapes', 'moblie', 'laptop', 'tv', 'fridge']

# %%
print(main_shop[0])
print(main_shop[3])
print(main_shop[2][1])
# Out:
# mango
# grapes
# r

# %%
main_shop.sort()
print(main_shop)
# Out:
# ['banana', 'fridge', 'grapes', 'laptop', 'mango', 'moblie', 'orange', 'tv']

# %%
print("the first item i will buy that is ",main_shop[0])
olditem = main_shop[0]
del main_shop[0]
print("i bought ",olditem)
print("my shopping list is now ",main_shop)
# Out:
# the first item i will buy that is  banana
# i bought  banana
# my shopping list is now  ['fridge', 'grapes', 'laptop', 'mango', 'moblie', 'orange', 'tv']

# %%
#pop
main_shop.pop()
print(main_shop.index("grapes"))
# Out:
# 1

# %%
#count
print(main_shop.count("mango"))
# Out:
# 1

# %%
shop2=main_shop
print(shop2)
# Out:
# ['fridge', 'grapes', 'laptop', 'mango', 'moblie', 'orange']

# %%
main_shop.clear()
print(main_shop)
# Out:
# []

# %%
list1 = [1, 2, 3, 4, 5,6,7,2,9,2,1,10]
print(list1.count(2))
list1.reverse()
print(list1)
list2 = [10, 20, 30]
print(list1+list2)
# Out:
# 3
# [10, 1, 2, 9, 2, 7, 6, 5, 4, 3, 2, 1]
# [10, 1, 2, 9, 2, 7, 6, 5, 4, 3, 2, 1, 10, 20, 30]

# %%
list3 = list2.copy()
print(list3)
print(id(list2))
print(id(list3))
# Out:
# [10, 20, 30]
# 2523134951232
# 2523139993600
