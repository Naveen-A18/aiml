# %%
s=eval("5+10")
print(s)
# Out:
# 15

# %%
#evalute the string as a python expression
x= eval(input("enter the expression:"))
print(x)
# Out:
# 4

# %%
def wish():
    print("hello good afternoon")
wish()
wish()
wish()
# Out:
# hello good afternoon
# hello good afternoon
# hello good afternoon
