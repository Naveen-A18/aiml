# %%
 #exception erroe
##construct:try,expect,finally,raise

# %%
a=int(input("enter a value :"))
b=int(input("enter b value :"))
c=a/b
print("a =",a)
print("b =",b)
print("c=(a/b) =",c)
# Out:
# a = 4
# b = 2
# c=(a/b) = 2.0

# %%
try:
    print(10/0)
except ZeroDivisionError:
    print(10/2)
# Out:
# 5.0

# %%
try:
    a =int(input("enter a value:"))
    b = int(input("enter b value:"))
    c=a/b
    print(c)
except Exception as e:
    print("exception catch",e)
# Out:
# exception catch invalid literal for int() with base 10: 'h'

# %%
try:
    x =int(input("enter first number:"))
    y= int(input("enter the second number:"))
    print(x/y)
except ZeroDivisionError:
    print("cant divide by zero")
except ValueError:
    print("pleasse provide int value only")
# Out:
# pleasse provide int value only

# %%
try:
    # we are not define variable j
    print(j)
except NameError:
    print("please define the variable")
# except :
finally:
    print("Name error exception solved the problem, dont worry ")
# Out:
# please define the variable
# Name error exception solved the problem, dont worry
