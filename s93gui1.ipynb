# %%
from tkinter import *
y = Tk()
y.title("acharya")
y.geometry("500x400")
y.config(bg="gray")
def submit():
    print("hi how are you")
l1=Label(y,text="Acharya institute of technology")
l1.pack()
l2=Label(y,text="bengalure")
l2.pack()
e1 =Entry(y,)
e1.place(x=200,y=100)
b1=Button(y,text="click",command=submit).place(x=200,y=200)
y.mainloop() #program run until user wont close
# Out:
# hi how are you
