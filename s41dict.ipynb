# %%
dict={}
print(type(dict))
# Out:
# <class 'dict'>

# %%
my_dict = {"name":"acharya","age":19}
print(my_dict)
my_dict["age"]=20
print(my_dict)
my_dict["address"]="India"
print(my_dict)
my_dict.clear()
print(my_dict)
my_dict["address"]="India"
my_dict["age"]=21
print(my_dict.keys())
print(my_dict.items())
# Out:
# {'name': 'acharya', 'age': 19}
# {'name': 'acharya', 'age': 20}
# {'name': 'acharya', 'age': 20, 'address': 'India'}
# {}
# dict_keys(['address', 'age'])
# dict_items([('address', 'India'), ('age', 21)])

# %%
print(my_dict)
my_dict.get("age")
print(my_dict.pop("age"))
# Out:
# {'address': 'India'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 3
#       1 print(my_dict)
#       2 my_dict.get("age")
# ----> 3 print(my_dict.pop("age"))
#
# KeyError: 'age'

# %%
print(my_dict)
# Out:
# {'address': 'India'}

# %%
my_dict = {"name":"acharya","age":19}
dict2 = {"name":"naveen","age":19}
my_dict.update(dict2)
print(my_dict)
# Out:
# {'name': 'naveen', 'age': 19}

# %%
students = {"student1":{"name":"naveen","age":19},
            "student2":{"name":"chandan","age":19}}
print(students)
# Out:
# {'student1': {'name': 'naveen', 'age': 19}, 'student2': {'name': 'chandan', 'age': 19}}

# %%
trans={"name":"naveen"}
print(trans["name"])
# Out:
# naveen
