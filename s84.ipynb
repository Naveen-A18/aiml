# %%
def generateTable(n):
    table = ""
    for i in range(1, 11):
        table += f"{n} X {i} = {n*i}\n"
    with open(f"DAY9/table/table{n}.txt", "w") as f:
        f.write(table)
for i in range(1, 11):
    generateTable(i)
